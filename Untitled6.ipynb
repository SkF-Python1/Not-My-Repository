# %% [markdown]
# <a href="https://colab.research.google.com/github/SkF-Python1/Not-My-Repository/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neattext
import pandas as pd
import requests
import neattext.functions as nfx

def fetch_query(query):
    base_url = f'https://www.google.com/search?q="{query}"'
    r = requests.get(base_url)
    return r.text

# df = pd.read_excel('USCA Top Account List.xlsx')
# search = df['URLS']

# sites = []; companies = []
# for _ in range(600):
#     text = fetch_query(search[_])
#     if 'maps.google' or 'linkedin' in nfx.extract_urls(text)[2]:
#       sites.append(nfx.extract_urls(text)[3])
#     elif 'google.com' in nfx.extract_urls(text)[3]:
#       sites.appned(nfx.extract_urls(text)[4])
#     elif 'search?q=' in nfx.extract_urls(text)[2]:
#       break
#     else:
#       sites.append(nfx.extract_urls(text)[2])
#     print('No.',_)
#     print(sites[_])
#     companies.append(search[_])

# new_df = pd.DataFrame((companies,sites)).T
# new_df.columns = ['Company','Domain']
# new_df.to_csv('Result2.csv', index =False)

# %%
x = """\
Paramount
Genesys
Perficient
Expedia Group
LTIMindtree
PayPal
Autodesk
DXC Technology
Apple
Workday
Randstad Sourceright
GlobalLogic
Tech Mahindra
Photon
Coforge
Amazon
Visa
Fidelity Investments
Dell Technologies
Oracle
Meta
Block
Konica Minolta Business Solutions U.S.A., Inc.
NVIDIA
Encora Inc.
ServiceNow
Microsoft
Rockwell Automation
HCL Technologies
Siemens Digital Industries Software
Apexon
LinkedIn
Akamai Technologies
ADP
RingCentral
Oracle Cerner Corporation
Change Healthcare
TikTok
Kellogg Company
Heidi Glickman and Associates
Target
Ally
Amazon Web Services (AWS)
Verizon
Salesforce
CDW
Softtek
TD SYNNEX
IFS
Ford Motor Company
Toyota North America
PwC
WESCO Distribution
Nuance Communications
Twilio
Activision Blizzard
Honeywell
InterSystems
ManTech
Corning Incorporated
Intel Corporation
RSM
Ascendion
Red Hat
Self
Wipro
Chewy
IBM
Avon
Atlassian
Accenture
Wayfair
UKG (Ultimate Kronos Group)
Avanade
ExxonMobil
EPAM - DEP
DocuSign
VMware
Mailchimp
InspiHRed Mission
Nordstrom
Hewlett Packard Enterprise
SAS
DoorDash
Trimble Inc.
Electronic Arts (EA)
Gartner
Halma plc
Citrix
PlayStation
Mastercard
NetEase Games
Carvana
Experian
TransUnion
Rakuten
Google
Ericsson
Resideo
UST
Infosys
Slalom
Honeywell FM&T
Warner Bros. Discovery
Nike
Intuit
Airbnb
ManpowerGroup
The Goodyear Tire & Rubber Company
Dun & Bradstreet
CDK Global
Infosys BPO
Cisco
Infor
Dell
AN GLOBAL US
Kinship
Boston Consulting Group (BCG)
Couchbase
Pegasystems
Zoom
Qualtrics
SAP
EY
Adobe
Indeed.com
State Street
PTC
athenahealth
Stride, Inc.
Sage Intacct, Inc.
Thomson Reuters
Teradata
Deluxe Corporation
Netflix
Peloton Interactive
Wiley
John Deere
TE Connectivity
Booz Allen Hamilton
Cognizant
Twitter
Walmart Global Tech
Persistent Systems
National Instruments
Wipro Limited
HCL AMERICA INC
MiTek
Siemens USA - Smart Infrastructure - Building Robotics, Inc.
Under Armour
Freddie Mac
Red Hat, Inc.
WEX
IBM Global Business Services
Unity Technologies
TEKsystems
Varian Medical Systems
AMD
GeBBS Healthcare Solutions
CSL Behring
American Express
Carrier
NetSuite
Yale University
Intel
Stryker
BCforward
UST Global
ServiceTrade
CI&T
Teleperformance
Prince George's County
AMS
Shopify
On Deck
RELX
CGI
Sutherland
Talkdesk
Silicon Valley Bank
Khoros
Chief
Amadeus
Paraform
Symantec
Independent Consultant
ENO8
AB InBev
Deloitte Government and Public Serv
EPAM Systems
ICF
Amentum
Valtech
Burlington Stores, Inc.
Walmart Labs
L3Harris Technologies
A.P. Moller - Maersk
Bosch USA
ACS Solutions
Epsilon
Tata Consultancy Services
Tata Group
PCLiquidations
Zscaler
Capital Group
iHeartMedia
ION
Dexcom
Hexagon Manufacturing Intelligence
KLA
Mission Technologies, a division of HII
Hyperloop Transportation Technologies, Inc.
Confidential/Start ups
Fluidra North America
Dish Network
Informa
CGI Federal
CitiusTech
Endava
Honeywell Recruitment (RPO – Randstad)
Keysight Technologies
Battelle
MilliporeSigma
Meta (formerly Facebook)
Ajace Inc
loanDepot
Slalom Consulting
KPMG US
Fortinet
Twilio Inc.
Synechron
ABB
Confidential
Micro Focus
Qualcomm
PeopleReady
Endava North America
Collabera Inc.
Comcast
IBM iX
Chamberlain Group
ProQuest (aquired by Clarivate in January 2022)
UnitedHealth Group
Visionet Systems Inc.
BAE Systems, Inc.
California Governor's Office of Emergency Services
CSRA Inc
Santander Bank, N.A.
"""
search = x.splitlines()

# %%
# !pip install neattext
# import pandas as pd
# import requests
# import neattext.functions as nfx

def fetch_query(query):
    base_url = f'https://www.google.com/search?q={query}+Company'
    r = requests.get(base_url)
    return r.text

# %%
import json

def autobit(query):
  base_url = f'https://autocomplete.clearbit.com/v1/companies/suggest?query={query}'
  r = requests.get(base_url)
  y = json.loads(r.text)
  try:
    return y[0]['domain']
  except:
    return y

sites = []
for _ in range(len(search)):
  sites.append(autobit(search[_]))

pd.DataFrame((search,sites)).T.to_csv('Domains.csv', index = False)

# %%
sites

# %%
import json

def autobit(query):
  base_url = f'https://autocomplete.clearbit.com/v1/companies/suggest?query={query}'
  r = requests.get(base_url)
  y = json.loads(r.text)
  return y[0]['domain']

sites = []
for _ in range(len(search)):
  text = fetch_query(search[_])

pd.DataFrame((search,sites)).T.to_csv('Fin13.csv', index = False, header=None)

autobit('RingCentral')
# Out:
# 'ringcentral.com'

# %%
sites = []
for _ in range(len(search)):
  text = fetch_query(search[_])
  res = nfx.extract_urls(text)
  for k in range(len(res)):
    if search[_] in res[k]:
      sites.append([res[k]])
      break

# %%
sites = []; companies = []
for _ in range(699,1400):
    text = fetch_query(search[_])
    if 'maps.google' or 'linkedin' in nfx.extract_urls(text)[2]:
      sites.append(nfx.extract_urls(text)[3])
    elif 'google.com' in nfx.extract_urls(text)[3]:
      sites.appned(nfx.extract_urls(text)[4])
    elif 'search?q=' in nfx.extract_urls(text)[2]:
      break
    else:
      sites.append(nfx.extract_urls(text)[2])
    print('No.',_)
    print(sites[_-699])
    companies.append(search[_])

# %%
import re
for line in sites:
  urls = re.findall('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', line)
  print(urls)

# %%
def fetch_query(query):
    base_url = f'https://www.google.com/search?q={query}+beds'
    r = requests.get(base_url)
    return r.text


comps = """Kaiser Permanente
HCA Healthcare
AdventHealth
Cleveland Clinic
Banner Health
Baylor Scott & White Health
Mount Sinai Health System
New York Presbyterian
DaVita
The University of Texas MD Anderson Cancer Center
University Hospitals
Montefiore Medical Center
UCHealth
Tenet Health
Indiana University Health
Atrium Health
Massachusetts General Hospital
Cedars-Sinai
Children's Hospital of Philadelphia
Concentra
Mercy Health
Universal Health Services
Beaumont Health
Allina Health
Johns Hopkins Medicine
Houston Methodist
Henry Ford Health System
Lehigh Valley Health Network
Northside Hospital
Bon Secours
Mercy
Ochsner Health
INTEGRIS Health
Sanford Health
VCU Health
Rush
Cincinnati Children's Hospital Medical Center
Emory Healthcare
Hartford HealthCare
Memorial Sloan Kettering Cancer Center
Loma Linda University
BayCare Health System
Children's Healthcare of Atlanta
Allegheny Health Network
Brigham and Women's Hospital
Main Line Health
Memorial Healthcare System
Froedtert & The Medical College of Wisconsin
Baptist Health
Steward Health Care
WellSpan Health
Dartmouth-Hitchcock
Community Health Network
TeamHealth
Memorial Hermann
MultiCare
Rochester Regional Health
Select Medical
Piedmont Healthcare
Hackensack University Medical Center
Baptist Health South Florida
Mass General Brigham
St. Jude Children's Research Hospital
RWJBarnabas Health
Beth Israel Deaconess Medical Center
McLaren
Baystate Health
Children's Hospital Colorado
AMITA Health
The US Oncology Network
Children's National
Parkland Health & Hospital System
Aspen Dental
University of Maryland Medical Center
UCLA Health
Prisma Health
Advocate Health Care
PIH Health
Pacific Dental Services
SCL Health
Cooper University Health Care
Spectrum Health
Parkview Hospital
Denver Health
Beacon Health Options
MemorialCare
AtlantiCare
Essentia Health
Wellmed Medical
Saint Lukeâ€™s Health System
TriHealth
UChicago Medicine
Summa Health
UW Health
Einstein Healthcare Network
Community Health Systems
Lee Health
HSS Hospital for Special Surgery
Athletico Physical Therapy
University of Mississippi Medical Center
Tufts Medical Center
Centura Health
Sarasota Memorial Health Care System
Center for Autism and Related Disorders (CARD)
Premise Health
John Muir Health
Marshfield Clinic Health System
The Queen's Health Systems
The Carle Foundation Hospital
Memorial Health System
Swedish Medical Center
West Virginia University Health System
Ballad Health
MEDNAX
UC Health
Northeast Georgia Health System
Lifespan
Saint Francis Health System
Methodist Le Bonheur Healthcare
Carilion Clinic
Albany Medical Center
LifeBridge Health
Envision Physician Services
